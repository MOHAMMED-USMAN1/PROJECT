# %%
import pandas as pd
df=pd.read_excel(r"C:\Users\MOHAMMED USMAN\Dropbox\My PC (LAPTOP-8CN5SU1D)\Downloads\cleanedData_final.xlsx")
df
# Out:
#                                                     url  ... Catering
# 0     https://www.zomato.com/bangalore/jalsa-banasha...  ...      yes
# 1     https://www.zomato.com/bangalore/spice-elephan...  ...       no
# 2     https://www.zomato.com/SanchurroBangalore?cont...  ...      yes
# 3     https://www.zomato.com/bangalore/addhuri-udupi...  ...      yes
# 4     https://www.zomato.com/bangalore/grand-village...  ...      yes
# ...                                                 ...  ...      ...
# 1286  https://www.zomato.com/bangalore/cafe-arabica-...  ...      yes
# 1287  https://www.zomato.com/bangalore/pizza-on-the-...  ...      yes
# 1288  https://www.zomato.com/bangalore/smoor-bannerg...  ...       no
# 1289  https://www.zomato.com/bangalore/kafe-nook-btm...  ...      yes
# 1290  https://www.zomato.com/bangalore/kumbha-bhojan...  ...       no
#
# [1291 rows x 20 columns]

# %%
banashankari= df[df['address'] == 'Banashankari']
print(banashankari)
# Out:
# Empty DataFrame
# Columns: [url, address, name, online_order, book_table, rate, votes, phone, location, rest_type, cuisines, approx_cost_for_two_people, reviews_list, menu_item, listed_in_type, listed_in_city, payMode, Discount, Capacity, Catering]
# Index: []
