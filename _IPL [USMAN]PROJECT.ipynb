# %%
import pandas as pd

# %%
#reading the file
df=pd.read_excel(r'C:\Users\MOHAMMED USMAN\Dropbox\My PC (LAPTOP-8CN5SU1D)\Downloads\IPL_Matches_2008-2020 - Copy.xlsx')
df
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.shape
# Out:
# (816, 17)

# %%
#schema of ipl project
df.dtypes
# Out:
# id                          int64
# city                       object
# date               datetime64[ns]
# player_of_match            object
# venue                      object
# neutral_venue               int64
# team1                      object
# team2                      object
# toss_winner                object
# toss_decision              object
# winner                     object
# result                     object
# result_margin             float64
# eliminator                 object
# method                     object
# umpire1                    object
# umpire2                    object
# dtype: object

# %%
'''
 Splitting the second column to get the information regarding the city
which conducted IPL matches so far 

'''
df['city']
# Out:
# 0       Bangalore
# 1      Chandigarh
# 2           Delhi
# 3          Mumbai
# 4         Kolkata
#           ...
# 811         Dubai
# 812         Dubai
# 813     Abu Dhabi
# 814     Abu Dhabi
# 815         Dubai
# Name: city, Length: 816, dtype: object

# %%
'''
Find out the city names which conducted maximum number of IPL
matches using pandas

'''
city_counts = df['city'].value_counts()
city_counts.head(1)
# Out:
# city
# Mumbai    101
# Name: count, dtype: int64

# %%
'''filter out the match data which were conducted in city Bangalore and
store the same data into the file'''
bangalore = df[df['city'] == 'Bangalore']
bangalore
# Out:
#           id       city       date  player_of_match                  venue  \
# 0     335982  Bangalore 2008-04-18      BB McCullum  M Chinnaswamy Stadium
# 10    335992  Bangalore 2008-04-26        SR Watson  M Chinnaswamy Stadium
# 14    335996  Bangalore 2008-04-28         MS Dhoni  M Chinnaswamy Stadium
# 24    336006  Bangalore 2008-05-05      S Sreesanth  M Chinnaswamy Stadium
# 30    336012  Bangalore 2008-05-28     CRD Fernando  M Chinnaswamy Stadium
# ..       ...        ...        ...              ...                    ...
# 606  1082621  Bangalore 2017-04-27           AJ Tye  M Chinnaswamy Stadium
# 618  1082633  Bangalore 2017-05-05   Sandeep Sharma  M Chinnaswamy Stadium
# 621  1082636  Bangalore 2017-05-07        SP Narine  M Chinnaswamy Stadium
# 633  1082648  Bangalore 2017-05-17  NM Coulter-Nile  M Chinnaswamy Stadium
# 634  1082649  Bangalore 2017-05-19        KV Sharma  M Chinnaswamy Stadium
#
# ...

# %%
bangalore.to_csv('matches_bangalore.csv', index=False)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\MOHAMMED USMAN'

# %%
'''
Now display the data which is stored in our file. consist of matches
which were played excluding the city Bangalore
'''
import pandas as pd

df = pd.read_csv('matches_bangalore.csv')
df
# Out:
#          id       city        date  player_of_match                  venue  \
# 0    335982  Bangalore  2008-04-18      BB McCullum  M Chinnaswamy Stadium
# 1    335992  Bangalore  2008-04-26        SR Watson  M Chinnaswamy Stadium
# 2    335996  Bangalore  2008-04-28         MS Dhoni  M Chinnaswamy Stadium
# 3    336006  Bangalore  2008-05-05      S Sreesanth  M Chinnaswamy Stadium
# 4    336012  Bangalore  2008-05-28     CRD Fernando  M Chinnaswamy Stadium
# ..      ...        ...         ...              ...                    ...
# 60  1082621  Bangalore  2017-04-27           AJ Tye  M Chinnaswamy Stadium
# 61  1082633  Bangalore  2017-05-05   Sandeep Sharma  M Chinnaswamy Stadium
# 62  1082636  Bangalore  2017-05-07        SP Narine  M Chinnaswamy Stadium
# 63  1082648  Bangalore  2017-05-17  NM Coulter-Nile  M Chinnaswamy Stadium
# 64  1082649  Bangalore  2017-05-19        KV Sharma  M Chinnaswamy Stadium
#
# ...

# %%
'''find out the player with most man of the matches'''
player_counts = df['player_of_match'].value_counts()
print(player_counts.head(1))
# Out:
# player_of_match
# AB de Villiers    23
# Name: count, dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])

# Filter rows for the year 2015
matches_2015 = df[df['date'].dt.year == 2015]


matches_2015
# Out:
#          id           city       date  player_of_match  \
# 458  829705        Kolkata 2015-04-08         M Morkel
# 459  829707        Chennai 2015-04-09          A Nehra
# 460  829709           Pune 2015-04-10      JP Faulkner
# 461  829711        Chennai 2015-04-11      BB McCullum
# 462  829713        Kolkata 2015-04-11         CH Gayle
# 463  829715          Delhi 2015-04-12         DJ Hooda
# 464  829717         Mumbai 2015-04-12        GJ Bailey
# 465  829719      Bangalore 2015-04-13        DA Warner
# 466  829721      Ahmedabad 2015-04-14        SPD Smith
# 467  829723        Kolkata 2015-04-30       AD Russell
# 468  829725           Pune 2015-04-15       MA Agarwal
# 469  829727  Visakhapatnam 2015-04-16        AM Rahane
# 470  829729         Mumbai 2015-04-17          A Nehra
# 471  829731  Visakhapatnam 2015-04-18        JP Duminy
# 472  829733           Pune 2015-04-18       AD Russell
# 473  829735      Ahmedabad 2015-04-19        AM Rahane
# ...

# %%
df.describe()
# Out:
#                  id                           date  neutral_venue  \
# count  8.160000e+02                            816     816.000000
# mean   7.563496e+05  2014-04-13 19:07:03.529411840       0.094363
# min    3.359820e+05            2008-04-18 00:00:00       0.000000
# 25%    5.012278e+05            2011-04-26 18:00:00       0.000000
# 50%    7.292980e+05            2014-04-23 12:00:00       0.000000
# 75%    1.082626e+06            2017-04-30 00:00:00       0.000000
# max    1.237181e+06            2020-11-10 00:00:00       1.000000
# std    3.058943e+05                            NaN       0.292512
#
#        result_margin
# count     799.000000
# mean       17.321652
# min         1.000000
# 25%         6.000000
# 50%         8.000000
# 75%        19.500000
# max       146.000000
# std        22.068427
